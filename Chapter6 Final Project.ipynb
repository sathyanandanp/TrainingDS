# %%
# !pip install pandas
# !pip install ipython-sql prettytable 

import prettytable

prettytable.DEFAULT = 'DEFAULT'
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import csv, sqlite3

con = sqlite3.connect("FinalDB.db")
cur = con.cursor()

# %%
# !pip install ipython-sql
# %load_ext sql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# %sql sqlite:///FinalDB.db

# %%
import pandas

df = pandas.read_csv(r"C:\Users\ajith\Downloads\ChicagoCrimeData.csv")

df.to_sql("Crime_Data", con, if_exists='replace', index=False,method="multi")
df
# Out:
#            ID CASE_NUMBER        DATE                     BLOCK  IUCR  \
# 0     3512276    HK587712  2004-08-28        047XX S KEDZIE AVE   890
# 1     3406613    HK456306  2004-06-26  009XX N CENTRAL PARK AVE   820
# 2     8002131    HT233595  2011-04-04        043XX S WABASH AVE   820
# 3     7903289    HT133522  2010-12-30      083XX S KINGSTON AVE   840
# 4    10402076    HZ138551  2016-02-02           033XX W 66TH ST   820
# ..        ...         ...         ...                       ...   ...
# 528  10453948    HZ192829  2016-03-01           028XX E 79TH ST  1055
# 529  10397129    HZ133234  2016-01-29       006XX W HARRISON ST  5114
# 530   3269495    HJ747227  2003-11-08           012XX W 81ST ST   510
# 531  10840565    JA143710  2017-02-06        009XX N KARLOV AVE  5073
# 532   1326195     G021609  2001-01-11       087XX S ESCANABA AV  9901
#
#                          PRIMARY_TYPE  \
# 0                               THEFT
# 1                               THEFT
# ...

# %%
df = pandas.read_csv(r"C:\Users\ajith\Downloads\ChicagoPublicSchools.csv")

df.to_sql("School_Data", con, if_exists='replace', index=False,method="multi")
df
# Out:
#      School_ID                                     NAME_OF_SCHOOL  \
# 0       610038                  Abraham Lincoln Elementary School
# 1       610281  Adam Clayton Powell Paideia Community Academy ...
# 2       610185                Adlai E Stevenson Elementary School
# 3       609993                    Agustin Lara Elementary Academy
# 4       610513                      Air Force Academy High School
# ..         ...                                                ...
# 561     610172                William T Sherman Elementary School
# 562     609844                 William W Carter Elementary School
# 563     610088                Wolfgang A Mozart Elementary School
# 564     609977               Woodlawn Community Elementary School
# 565     610392                 World Language Academy High School
#
#     Elementary, Middle, or High School         Street_Address     City State  \
# 0                                   ES        615 W Kemper Pl  Chicago    IL
# ...

# %%
df = pandas.read_csv(r"C:\Users\ajith\Downloads\ChicagoCensusData.csv")

df.to_sql("Census_Data", con, if_exists='replace', index=False,method="multi")

df
# Out:
#     COMMUNITY_AREA_NUMBER COMMUNITY_AREA_NAME  PERCENT_OF_HOUSING_CROWDED  \
# 0                     1.0         Rogers Park                         7.7
# 1                     2.0          West Ridge                         7.8
# 2                     3.0              Uptown                         3.8
# 3                     4.0      Lincoln Square                         3.4
# 4                     5.0        North Center                         0.3
# ..                    ...                 ...                         ...
# 73                   74.0     Mount Greenwood                         1.0
# 74                   75.0         Morgan Park                         0.8
# 75                   76.0              O'Hare                         3.6
# 76                   77.0           Edgewater                         4.1
# 77                    NaN             CHICAGO                         4.7
#
#     PERCENT_HOUSEHOLDS_BELOW_POVERTY  PERCENT_AGED_16__UNEMPLOYED  \
# ...

# %%
# %sql SELECT name FROM sqlite_master WHERE type='table'
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Crime_Data',), ('School_Data',), ('Census_Data',)]

# %% [markdown]
# Problem 1 Find the total number of crimes recorded in the CRIME table

# %%
# %sql select count(*) from Crime_Data
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(533,)]

# %% [markdown]
# Problem 2
# List community area names and numbers with per capita income less than 11000.

# %%
# %sql SELECT COMMUNITY_AREA_NUMBER, COMMUNITY_AREA_NAME FROM Census_Data where PER_CAPITA_INCOME < 11000
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(26.0, 'West Garfield Park'),
#  (30.0, 'South Lawndale'),
#  (37.0, 'Fuller Park'),
#  (54.0, 'Riverdale')]

# %% [markdown]
# Problem 3 List all case numbers for crimes involving minors?(children are not considered minors for the purposes of crime analysis)

# %%
# %sql SELECT CASE_NUMBER FROM Crime_Data where DESCRIPTION LIKE '%MINOR%'
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('HL266884',), ('HK238408',)]

# %% [markdown]
# Problem 4 List all kidnapping crimes involving a child?

# %%
# %sql select * from Crime_Data where PRIMARY_TYPE = 'KIDNAPPING' and DESCRIPTION LIKE '%CHILD%'
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(5276766, 'HN144152', '2007-01-26', '050XX W VAN BUREN ST', '1792', 'KIDNAPPING', 'CHILD ABDUCTION/STRANGER', 'STREET', 0, 0, 1533, 15, 29.0, 25.0, '20', 1143050.0, 1897546.0, 2007, 41.87490841, -87.75024931, '(41.874908413, -87.750249307)')]

# %% [markdown]
# Problem 5 List the kind of crimes that were recorded at schools. (No repetitions)

# %%
# %sql select DISTINCT(PRIMARY_TYPE) from Crime_Data where LOCATION_DESCRIPTION LIKE '%SCHOOL%'
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('BATTERY',),
#  ('CRIMINAL DAMAGE',),
#  ('NARCOTICS',),
#  ('ASSAULT',),
#  ('CRIMINAL TRESPASS',),
#  ('PUBLIC PEACE VIOLATION',)]

# %% [markdown]
# Problem 6 List the type of schools along with the average safety score for each type.

# %%
df = pandas.read_csv(r"C:\Users\ajith\Downloads\ChicagoPublicSchools2.csv")

df.to_sql("School_Data", con, if_exists='replace', index=False,method="multi")
df
# Out:
#      School_ID                                     NAME_OF_SCHOOL  \
# 0       610038                  Abraham Lincoln Elementary School
# 1       610281  Adam Clayton Powell Paideia Community Academy ...
# 2       610185                Adlai E Stevenson Elementary School
# 3       609993                    Agustin Lara Elementary Academy
# 4       610513                      Air Force Academy High School
# ..         ...                                                ...
# 561     610172                William T Sherman Elementary School
# 562     609844                 William W Carter Elementary School
# 563     610088                Wolfgang A Mozart Elementary School
# 564     609977               Woodlawn Community Elementary School
# 565     610392                 World Language Academy High School
#
#     ELEMENTARY_MIDDLE_HIGH_SCHOOL         Street_Address     City State  \
# 0                              ES        615 W Kemper Pl  Chicago    IL
# ...

# %%
# %sql SELECT AVG(SAFETY_SCORE), ELEMENTARY_MIDDLE_HIGH_SCHOOL FROM School_Data GROUP BY ELEMENTARY_MIDDLE_HIGH_SCHOOL
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(49.52038369304557, 'ES'), (49.62352941176471, 'HS'), (48.0, 'MS')]

# %% [markdown]
# Problem 7 List 5 community areas with highest % of households below poverty line

# %%
# %sql SELECT COMMUNITY_AREA_NAME, PERCENT_HOUSEHOLDS_BELOW_POVERTY FROM Census_Data ORDER BY PERCENT_HOUSEHOLDS_BELOW_POVERTY DESC LIMIT 5
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Riverdale', 56.5),
#  ('Fuller Park', 51.2),
#  ('Englewood', 46.6),
#  ('North Lawndale', 43.1),
#  ('East Garfield Park', 42.4)]

# %% [markdown]
# Problem 8 Which community area is most crime prone? Display the coumminty area number only.

# %%
# %%sql
# SELECT COMMUNITY_AREA_NUMBER ,COUNT(COMMUNITY_AREA_NUMBER) AS FREQUENCY
# FROM Crime_Data
# GROUP BY COMMUNITY_AREA_NUMBER
# ORDER BY COUNT(COMMUNITY_AREA_NUMBER) DESC
# LIMIT 1;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(25.0, 43)]

# %% [markdown]
# Problem 9 Use a sub-query to find the name of the community area with highest hardship index

# %%
# %%sql
# SELECT COMMUNITY_AREA_NAME, HARDSHIP_INDEX FROM Census_Data ORDER BY HARDSHIP_INDEX DESC LIMIT 1;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Riverdale', 98.0)]

# %% [markdown]
# Problem 10 Use a sub-query to determine the Community Area Name with most number of crimes?

# %%
# %sql SELECT COMMUNITY_AREA_NAME FROM Census_Data WHERE (SELECT (MAX COUNT (COMMUNITY_AREA_NUMBER) FROM Crime_Data), Limit 1))
# Out:
#  * sqlite:///FinalDB.db
# (sqlite3.OperationalError) near "COUNT": syntax error
# [SQL: SELECT COMMUNITY_AREA_NAME FROM Census_Data WHERE (SELECT (MAX COUNT (COMMUNITY_AREA_NUMBER) FROM Crime_Data), Limit 1))]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %sql SELECT COMMUNITY_AREA_NAME FROM Census_Data WHERE HARDSHIP_INDEX IN (SELECT MAX(HARDSHIP_INDEX) FROM Census_Data);
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Riverdale',)]

# %%
# %sql SELECT MAX(COUNT(COMMUNITY_AREA_NUMBER) FROM Crime_Data)
# Out:
#  * sqlite:///FinalDB.db
# (sqlite3.OperationalError) near "FROM": syntax error
# [SQL: SELECT MAX(COUNT(COMMUNITY_AREA_NUMBER) FROM Crime_Data)]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %%sql
# SELECT COMMUNITY_AREA_NAME FROM Census_Data WHERE COMMUNITY_AREA_NUMBER = (SELECT COMMUNITY_AREA_NUMBER
# FROM Crime_Data
# GROUP BY COMMUNITY_AREA_NUMBER
# ORDER BY COUNT(COMMUNITY_AREA_NUMBER) DESC
# LIMIT 1)
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Austin',)]
